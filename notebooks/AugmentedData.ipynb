# %%
# !pip install transformers datasets torchaudio --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 75.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 11.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
# Transformers library
from transformers import (
    Wav2Vec2ForSequenceClassification,
    Wav2Vec2Processor,
    Wav2Vec2FeatureExtractor,
    TrainingArguments,
    Trainer,
    EarlyStoppingCallback
)

# %%
# PyTorch
import torch
from torch.utils.data import DataLoader

# Dataset handling
from datasets import Dataset, Audio

# Metrics
from sklearn.metrics import accuracy_score
import numpy as np

# File handling
import os
import shutil
import json

# Audio processing
import soundfile as sf

# Randomization
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls '/content/drive/MyDrive/Deep_Project/'
# Out:
# AugmentedData.json  loss_plot.png        TestData@                 wav2vec2-lora/
# Data@               new_data@            test_data.json            wav2vec2-lora-adapter_/
# labeled_data.json   predictions.npy      true_labels.npy
# lora@               RoyPlayingWithData/  wav2vec2-base_/
# losses.json         saved_models/        wav2vec2-base-finetuned/

# %% [markdown]
# #Here we train on the Augmented DATASET:

# %%
import json
from collections import Counter

# %%
#augmented_data_path='/content/drive/My Drive/AugmentedData'
# ROY CHANGED FOLDER
output_file = "/content/drive/MyDrive/Deep_Project/AugmentedData.json"

# %%
import os
print(os.path.exists(output_file))  # Should return True
# Out:
# True

# %%
# Load the JSON file
with open(output_file, "r") as f:
    data = json.load(f)

# Print the first 5 samples
print("First 5 samples:")
for sample in data[:5]:
    print(sample)

# Check the total number of samples
num_samples = len(data)
print(f"\nTotal number of samples: {num_samples}")

# Inspect keys in one sample
if num_samples > 0:
    print("\nKeys in a sample:")
    print(list(data[0].keys()))
    print("\nExample sample:")
    print(data[0])

# Check accent distribution
accent_distribution = Counter([entry["accent"] for entry in data])
print("\nAccent distribution:")
for accent, count in accent_distribution.items():
    print(f"{accent}: {count}")
# Out:
# First 5 samples:
# {'file_path': '/content/drive/My Drive/Deep_Project/RoyPlayingWithData/speaker1/arctic_b0418_vtlp.wav', 'speaker': 'speaker1', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/Deep_Project/RoyPlayingWithData/speaker1/arctic_b0121_time_stretch.wav', 'speaker': 'speaker1', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/Deep_Project/RoyPlayingWithData/speaker1/arctic_a0474_pitch_shift.wav', 'speaker': 'speaker1', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/Deep_Project/RoyPlayingWithData/speaker1/arctic_b0029_pitch_shift.wav', 'speaker': 'speaker1', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/Deep_Project/RoyPlayingWithData/speaker1/arctic_b0194_pitch_shift.wav', 'speaker': 'speaker1', 'accent': 'Arabic'}
#
# Total number of samples: 786
#
# Keys in a sample:
# ['file_path', 'speaker', 'accent']
#
# Example sample:
# {'file_path': '/content/drive/My Drive/Deep_Project/RoyPlayingWithData/speaker1/arctic_b0418_vtlp.wav', 'speaker': 'speaker1', 'accent': 'Arabic'}
#
# Accent distribution:
# Arabic: 393
# Spanish: 393

# %% [markdown]
# #Validate the dataset

# %%
import soundfile as sf

# %%
def is_valid_audio(file_path, current_speaker=None, last_speaker=None):
    try:
        # Log progress when the speaker changes
        if current_speaker != last_speaker:
            print(f"Processing files for speaker: {current_speaker}")

        # Open the file in "read mode" without loading it fully
        with sf.SoundFile(file_path, mode="r") as f:
            pass  # Successfully opened, no need to read data
        return True, current_speaker

    except Exception as e:
        # Log the problematic file and speaker
        print(f"Invalid file detected for speaker {current_speaker}: {file_path}, Error: {e}")
        return False, current_speaker

# %%
# Maximum number of files per speaker
MAX_FILES_PER_SPEAKER = 100

# Initialize a dictionary to track the number of files processed per speaker
speaker_file_count = {}

valid_data = []  # Store valid files

for item in data:
    speaker = item["speaker"]

    # Initialize the counter for the speaker if not already done
    if speaker not in speaker_file_count:
        speaker_file_count[speaker] = 0

    # Skip files if the maximum limit is reached for the speaker
    if speaker_file_count[speaker] >= MAX_FILES_PER_SPEAKER:
        continue

    # Check the validity of the file
    is_valid, current_speaker = is_valid_audio(
        item["file_path"],
        current_speaker=speaker,
        last_speaker=None,  # Not needed for this use case
    )

    if is_valid:
        valid_data.append(item)
        speaker_file_count[speaker] += 1  # Increment the counter for the speaker

print(f"Valid data collected for {len(speaker_file_count)} speakers.")
# Out:
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker1
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker2
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker3
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker4
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker17
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker18
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker19
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Processing files for speaker: speaker20
# Valid data collected for 8 speakers.

# %% [markdown]
# # Make the data compatible to work with huggingface & Add the linear layer to make our model supervised and good for classification

# %%
from transformers import Wav2Vec2FeatureExtractor

# %%
# Convert the filtered data into a Hugging Face Dataset
dataset = Dataset.from_list(valid_data)

# Ensure all audio files are loaded with the correct sampling rate
dataset = dataset.cast_column("file_path", Audio(sampling_rate=16000))

# %%
# Load Wav2Vec2 feature extractor
feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained("facebook/wav2vec2-large-xlsr-53")

# Map labels to integers
unique_accents = dataset.unique("accent")
label2id = {label: i for i, label in enumerate(unique_accents)}
id2label = {i: label for label, i in label2id.items()}

# ensure correct accents
print(f"Unique accents: {unique_accents}")
print(f"Label to ID mapping: {label2id}")
print(f"ID to Label mapping: {id2label}")

# Preprocessing function
def preprocess(batch):
    # Load audio and extract input values
    audio = batch["file_path"]["array"]
    inputs = feature_extractor(audio, sampling_rate=16000, return_tensors="pt", padding=True)
    batch["input_values"] = inputs.input_values[0]
    batch["labels"] = label2id[batch["accent"]]
    return batch

# Apply preprocessing
dataset = dataset.map(preprocess, remove_columns=["file_path", "accent", "speaker"])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/212 [00:00<?, ?B/s]
# Unique accents: ['Arabic', 'Spanish']
# Label to ID mapping: {'Arabic': 0, 'Spanish': 1}
# ID to Label mapping: {0: 'Arabic', 1: 'Spanish'}
# Map:   0%|          | 0/761 [00:00<?, ? examples/s]

# %%
# Split the dataset
train_test_split = dataset.train_test_split(test_size=0.2)
train_dataset = train_test_split["train"]
test_dataset = train_test_split["test"]

# Print the number of samples
print(f"Number of samples in the training set: {len(train_dataset)}")
print(f"Number of samples in the validation set: {len(test_dataset)}")
# Out:
# Number of samples in the training set: 608
# Number of samples in the validation set: 153

# %% [markdown]
# #Define the model

# %%
# Load pre-trained Wav2Vec2 model for classification
model = Wav2Vec2ForSequenceClassification.from_pretrained(
    "facebook/wav2vec2-large-xlsr-53",
    num_labels=len(unique_accents),
    label2id=label2id,
    id2label=id2label,
)
# Out:
# config.json:   0%|          | 0.00/1.77k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.27G [00:00<?, ?B/s]
# Some weights of Wav2Vec2ForSequenceClassification were not initialized from the model checkpoint at facebook/wav2vec2-large-xlsr-53 and are newly initialized: ['classifier.bias', 'classifier.weight', 'projector.bias', 'projector.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# #Define accuracy metric

# %%
# Define accuracy metric
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    accuracy = accuracy_score(labels, predictions)
    return {"accuracy": accuracy}

# %%
from transformers import TrainingArguments
import torch

# %%
# Define training arguments

training_args = TrainingArguments(
    output_dir="./results",               # Directory to save model and results
    evaluation_strategy="epoch",          # Evaluate at the end of each epoch
    logging_strategy="steps",             # Log every `logging_steps`
    logging_steps=10,                     # Log every 10 steps
    learning_rate=2e-5,                   # Learning rate
    per_device_train_batch_size=8,        # Batch size for training
    per_device_eval_batch_size=8,         # Batch size for evaluation
    num_train_epochs=20,                   # Total number of epochs
    weight_decay=0.01,                    # Weight decay
    save_strategy="epoch",                # Save model at each epoch
    logging_dir="./logs",                 # Directory for logs
    load_best_model_at_end=True,          # Load the best model at the end
    metric_for_best_model="accuracy",     # Metric for selecting the best model
    report_to="none",                     # Disable logging to external services
    fp16=True,  # Enable mixed precision training - GET RID OF THIS FOR ACCURACY!!!!!!!!!!!!!!!
)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
import os
os.environ["WANDB_DISABLED"] = "true"

# %%
import torch
if torch.cuda.is_available():
    print(f"GPU is available: {torch.cuda.get_device_name(0)}")
else:
    print("No GPU found. Please enable GPU in runtime settings.")

# Check the device being used by PyTorch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# GPU is available: NVIDIA A100-SXM4-40GB
# Using device: cuda

# %%
# Freeze feature extractor
for param in model.wav2vec2.feature_extractor.parameters():
    param.requires_grad = False

# Define Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=feature_extractor,  # Use feature extractor
    compute_metrics=compute_metrics,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=5)],  # Add early stopping
)

# Train the model
trainer.train()
# Out:
# <ipython-input-23-664453ad06c0>:6: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='1140' max='1520' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1140/1520 10:00 < 03:20, 1.90 it/s, Epoch 15/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.691000</td>
#       <td>0.695092</td>
#       <td>0.437908</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.677800</td>
#       <td>0.689354</td>
#       <td>0.575163</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.563700</td>
#       <td>0.543527</td>
#       <td>0.803922</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.379300</td>
#       <td>0.380530</td>
#       <td>0.895425</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.201300</td>
#       <td>0.174538</td>
#       <td>0.947712</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.135200</td>
#       <td>0.098007</td>
#       <td>0.973856</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.035800</td>
#       <td>0.338763</td>
#       <td>0.901961</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.181800</td>
#       <td>0.020022</td>
#       <td>0.993464</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.045800</td>
#       <td>0.264668</td>
#       <td>0.941176</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.215100</td>
#       <td>0.002442</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.150400</td>
#       <td>0.050156</td>
#       <td>0.986928</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.064300</td>
#       <td>0.001448</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.053500</td>
#       <td>0.117468</td>
#       <td>0.980392</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.033400</td>
#       <td>0.034930</td>
#       <td>0.993464</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.005600</td>
#       <td>0.187762</td>
#       <td>0.967320</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1140, training_loss=0.24775076205270333, metrics={'train_runtime': 602.425, 'train_samples_per_second': 20.185, 'train_steps_per_second': 2.523, 'total_flos': 1.500361246370861e+18, 'train_loss': 0.24775076205270333, 'epoch': 15.0})

# %%
# Save model and feature extractor FOR ROY!!!!!!!!!!!!!!!!!!!!!
model.save_pretrained("/content/drive/My Drive/Deep_Project/saved_models/augmented_model")
feature_extractor.save_pretrained("/content/drive/My Drive/Deep_Project/saved_models/augmented_model")

print("Model and feature extractor saved successfully!")
# Out:
# Model and feature extractor saved successfully!

# %% [markdown]
# #Test data on Augmentations

# %%
import json

# Define the path to the JSON file
json_file_path = '/content/drive/My Drive/TestData/test_data.json'

# Load the JSON file and convert it into a list
with open(json_file_path, 'r') as json_file:
    test_data_list = json.load(json_file)

# Print the list
print("\n✅ Loaded Test Data from JSON:")
for entry in test_data_list:
    print(entry)

# Summary
print(f"\nTotal files in the list: {len(test_data_list)}")
# Out:
# ✅ Loaded Test Data from JSON:
# {'file_path': '/content/drive/My Drive/TestData/arabic10.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic7.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic8.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic89.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic83.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic75.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic76.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic78.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic80.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic73.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic71.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic74.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic77.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic67.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic72.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic64.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic79.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic61.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic70.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic59.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic53.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic69.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic60.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic63.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic65.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic68.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic57.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic51.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic62.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic66.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic55.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic58.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic54.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic49.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic44.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic42.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic43.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic56.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic48.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic41.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic52.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic46.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic50.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic47.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic45.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic39.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic34.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic32.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic40.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic37.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic36.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic31.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic35.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic33.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic38.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic23.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic25.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic29.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic24.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic15.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic18.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic19.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic22.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic26.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic12.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic14.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic28.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic30.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic21.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic11.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic20.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic13.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic6.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic4.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic9.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic16.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic27.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic2.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic5.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic1.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic17.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic3.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic101.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic102.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic96.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic98.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic92.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic100.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic94.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic99.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic95.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic93.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic88.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic84.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic87.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic81.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic85.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic86.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic90.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic82.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic91.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/arabic97.wav', 'accent': 'Arabic'}
# {'file_path': '/content/drive/My Drive/TestData/spanish17.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish20.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish19.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish14.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish18.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish16.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish12.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish15.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish13.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish11.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish3.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish8.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish4.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish1.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish5.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish6.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish7.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish10.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish9.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish2.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish93.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish95.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish89.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish87.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish88.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish86.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish84.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish83.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish81.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish85.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish76.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish71.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish79.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish82.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish72.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish75.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish77.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish64.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish66.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish61.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish70.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish67.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish80.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish73.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish78.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish62.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish74.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish69.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish68.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish65.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish56.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish53.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish63.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish55.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish51.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish57.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish52.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish60.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish59.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish58.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish46.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish47.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish43.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish54.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish49.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish50.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish41.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish44.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish42.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish45.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish48.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish39.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish34.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish35.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish38.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish31.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish32.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish36.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish37.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish40.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish33.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish29.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish26.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish21.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish30.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish22.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish25.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish23.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish24.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish27.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish28.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish151.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish154.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish159.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish158.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish162.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish155.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish152.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish157.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish150.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish160.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish153.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish156.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish149.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish147.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish146.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish148.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish144.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish145.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish141.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish142.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish139.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish105.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish103.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish100.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish102.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish104.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish107.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish143.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish106.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish108.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish111.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish112.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish116.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish114.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish113.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish115.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish117.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish118.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish119.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish126.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish129.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish125.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish122.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish121.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish130.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish120.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish124.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish128.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish127.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish140.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish123.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish131.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish133.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish134.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish136.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish132.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish135.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish137.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish138.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish110.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish109.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish101.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish99.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish98.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish92.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish96.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish94.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish97.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish90.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish91.wav', 'accent': 'Spanish'}
# {'file_path': '/content/drive/My Drive/TestData/spanish161.wav', 'accent': 'Spanish'}
#
# Total files in the list: 264

# %%
import torch
from transformers import Wav2Vec2FeatureExtractor
import numpy as np
from sklearn.metrics import accuracy_score
from datasets import Dataset
from datasets import Audio

# Step 1: Load test_data.json
json_file_path = '/content/drive/My Drive/Deep_Project/test_data.json'
with open(json_file_path, 'r') as json_file:
    test_data_list = json.load(json_file)

print(f"\n✅ Loaded Test Data: {len(test_data_list)} samples")

# Step 2: Convert the test data to a Hugging Face Dataset
test_dataset = Dataset.from_list(test_data_list)

# Step 3: Load the feature extractor used during training
feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained(
    "/content/drive/My Drive/Deep_Project/saved_models/augmented_model"
)
# Out:
# ✅ Loaded Test Data: 264 samples

# %%
# Step 4: Preprocess test data
# Preprocess the test dataset
def preprocess_test_data(batch):
    # Convert audio to tensor using the feature extractor
    audio = batch["file_path"]["array"]
    features = feature_extractor(audio, sampling_rate=16000, return_tensors="pt", padding=True)
    batch["input_values"] = features.input_values[0]  # Extract the input_values tensor
    batch["labels"] = 1 if batch["accent"].lower() == "spanish" else 0  # Add labels
    return batch

# Apply preprocessing
test_dataset = test_dataset.cast_column("file_path", Audio(sampling_rate=16000))
test_dataset = test_dataset.map(preprocess_test_data, remove_columns=["file_path", "accent"])

# Step 5: Load the trained model
from transformers import Wav2Vec2ForSequenceClassification

model = Wav2Vec2ForSequenceClassification.from_pretrained(
    "/content/drive/My Drive/Deep_Project/saved_models/augmented_model"
)
model.eval()

# Step 6: Define a function to evaluate the model
from torch.utils.data import DataLoader
# Out:
# Map:   0%|          | 0/264 [00:00<?, ? examples/s]

# %%
from transformers import DataCollatorWithPadding

data_collator = DataCollatorWithPadding(
    tokenizer=feature_extractor,  # Use Wav2Vec2 feature extractor
    padding=True,
    max_length=16000,  # Set a reasonable max length in samples
)

# %%
# Move the model to the GPU and enable gradient checkpointing
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
model.gradient_checkpointing_enable()  # Enable gradient checkpointing to save memory


# Evaluate the model
def evaluate_model(dataset, model):
    model.eval()  # Set model to evaluation mode
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=2, collate_fn=data_collator)

    predictions = []
    labels = []

    # Clear CUDA cache to prevent fragmentation
    torch.cuda.empty_cache()

    for batch in dataloader:
        # Move input values and labels to the correct device
        input_values = batch["input_values"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels.extend(batch["labels"])  # Collect true labels

        with torch.no_grad():
            outputs = model(input_values=input_values, attention_mask=attention_mask).logits
            preds = torch.argmax(outputs, dim=-1).cpu().tolist()
            predictions.extend(preds)

    # Compute accuracy
    accuracy = accuracy_score(labels, predictions)
    print(f"\n✅ Test Dataset Accuracy: {accuracy * 100:.2f}%")
    return accuracy

# Evaluate the model
test_accuracy = evaluate_model(test_dataset, model)
